# %%
import requests
import pandas as pd

# %%
start_date = "2022-06-01"
end_date = "2022-06-10"
data_collection = "SENTINEL-2"
aoi = "POLYGON((4.220581 50.958859,4.521264 50.953236,4.545977 50.906064,4.541858 50.802029,4.489685 50.763825,4.23843 50.767734,4.192435 50.806369,4.189689 50.907363,4.220581 50.958859))'"

# %%
json = requests.get(f"https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Collection/Name eq '{data_collection}' and OData.CSC.Intersects(area=geography'SRID=4326;{aoi}) and ContentDate/Start gt {start_date}T00:00:00.000Z and ContentDate/Start lt {end_date}T00:00:00.000Z").json()
pd.DataFrame.from_dict(json['value']).head(5)
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  bb412273-69a3-5afa-8d2e-774f63e1c568
# 1  application/octet-stream  f83b6e00-8669-5f6c-96e1-f8c82dd98909
# 2  application/octet-stream  794333bd-1015-5a46-bd22-0f4b943897c5
# 3  application/octet-stream  550c10a8-3a31-5f28-8d68-e0b7086dbc8f
# 4  application/octet-stream  6db4f178-b416-5fe7-98d4-1cef9214a1fb
#
#                                                 Name  \
# 0  S2B_MSIL1C_20220601T103629_N0400_R008_T31UFS_2...
# 1  S2B_MSIL1C_20220601T103629_N0400_R008_T31UES_2...
# 2  S2B_MSIL2A_20220601T103629_N0400_R008_T31UES_2...
# 3  S2B_MSIL2A_20220601T103629_N0400_R008_T31UFS_2...
# 4  S2A_MSIL2A_20220606T103631_N0400_R008_T31UES_2...
#
#                 ContentType  ContentLength                   OriginDate  \
# 0  application/octet-stream              0  2022-06-01T15:15:13.475000Z
# 1  application/octet-stream              0  2022-06-01T15:17:31.386000Z
# 2  application/octet-stream              0  2022-06-01T17:21:07.927000Z
# 3  application/octet-stream              0  2022-06-01T17:40:10.814000Z
# 4  application/octet-stream              0  2022-06-06T20:23:16.212000Z
#
#                PublicationDate             ModificationDate  Online  \
# 0  2022-06-01T15:20:38.977256Z  2022-06-01T15:20:38.977256Z    True
# 1  2022-06-01T15:22:27.713076Z  2022-06-01T15:22:27.713076Z    True
# 2  2022-06-01T17:26:25.056082Z  2022-06-01T17:26:25.056082Z    True
# 3  2022-06-01T17:47:49.803842Z  2022-06-01T17:47:49.803842Z    True
# 4  2022-06-06T20:53:41.413565Z  2022-06-06T20:53:41.413565Z    True
#
#                   EvictionDate  \
# 0  9999-12-31T23:59:59.999999Z
# 1  9999-12-31T23:59:59.999999Z
# 2  9999-12-31T23:59:59.999999Z
# 3  9999-12-31T23:59:59.999999Z
# 4  9999-12-31T23:59:59.999999Z
#
#                                               S3Path Checksum  \
# 0  /eodata/Sentinel-2/MSI/L1C/2022/06/01/S2B_MSIL...       []
# 1  /eodata/Sentinel-2/MSI/L1C/2022/06/01/S2B_MSIL...       []
# 2  /eodata/Sentinel-2/MSI/L2A/2022/06/01/S2B_MSIL...       []
# 3  /eodata/Sentinel-2/MSI/L2A/2022/06/01/S2B_MSIL...       []
# 4  /eodata/Sentinel-2/MSI/L2A/2022/06/06/S2A_MSIL...       []
#
#                                          ContentDate  \
# 0  {'Start': '2022-06-01T10:36:29.024000Z', 'End'...
# 1  {'Start': '2022-06-01T10:36:29.024000Z', 'End'...
# 2  {'Start': '2022-06-01T10:36:29.024000Z', 'End'...
# 3  {'Start': '2022-06-01T10:36:29.024000Z', 'End'...
# 4  {'Start': '2022-06-06T10:36:31.024000Z', 'End'...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((4.4362457433229 ...
# 1  geography'SRID=4326;POLYGON ((4.0716897587579 ...
# 2  geography'SRID=4326;POLYGON ((4.0716897587579 ...
# 3  geography'SRID=4326;POLYGON ((4.4362457433229 ...
# 4  geography'SRID=4326;POLYGON ((4.0740131839748 ...
#
#                                         GeoFootprint
# 0  {'type': 'Polygon', 'coordinates': [[[4.436245...
# 1  {'type': 'Polygon', 'coordinates': [[[4.071689...
# 2  {'type': 'Polygon', 'coordinates': [[[4.071689...
# 3  {'type': 'Polygon', 'coordinates': [[[4.436245...
# 4  {'type': 'Polygon', 'coordinates': [[[4.074013...

# %%
url = f"https://download.dataspace.copernicus.eu/odata/v1/Products(a5ab498a-7b2f-4043-ae2a-f95f457e7b3b)/$value"

headers = {"Authorization": f"Bearer {keycloak_token}"}

# Create a session and update headers
session = requests.Session()
session.headers.update(headers)

# Perform the GET request
response = session.get(url, stream=True)

# Check if the request was successful
if response.status_code == 200:
    with open("product33.zip", "wb") as file:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:  # filter out keep-alive new chunks
                file.write(chunk)
else:
    print(f"Failed to download file. Status code: {response.status_code}")
    print(response.text)
